# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('organisation.csv')

# %%
df.head(10)
#to get first 10 rows default is 5
# Out:
#    Organization Id                     Name                         Website
# 0  FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1  6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2  0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 3  2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 4  9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
# 5  cC757116fe1C085           Henry-Thompson               http://morse.net/
# 6  219233e8aFF1BC3           Hansen-Everett           https://www.kidd.org/
# 7  ccc93DCF81a31CD            Mcintosh-Mora         https://www.brooks.com/
# 8  0B4F93aA06ED03e                 Carr Inc                http://ross.com/
# 9  738b5aDe6B1C6A5               Gaines Inc     http://sandoval-hooper.com/
#
#                              Country
# 0                   Papua New Guinea  \
# 1                            Finland
# ...

# %%
df.tail(12)
#to get bottom 12 rows default is 5
# Out:
#      Organization Id                    Name                  Website
# 94   4e91eD25f486110  Best, Wade and Shepard   https://zimmerman.com/  \
# 95   0a0bfFbBbB8eC7c            Holmes Group    https://mcdowell.org/
# 96   BA6Cd9Dae2Efd62                Good Ltd        http://duffy.com/
# 97   E7df80C60Abd7f9       Clements-Espinoza  http://www.flowers.net/
# 98   AFc285dbE2fEd24              Mendez Inc   https://www.burke.net/
# 99   e9eB5A60Cef8354          Watkins-Kaiser  http://www.herring.com/
# 100  4e91eD25f486110  Best, Wade and Shepard   https://zimmerman.com/
# 101  0a0bfFbBbB8eC7c            Holmes Group    https://mcdowell.org/
# 102  BA6Cd9Dae2Efd62                Good Ltd        http://duffy.com/
# 103  E7df80C60Abd7f9       Clements-Espinoza  http://www.flowers.net/
# 104  AFc285dbE2fEd24              Mendez Inc   https://www.burke.net/
# 105  e9eB5A60Cef8354          Watkins-Kaiser  http://www.herring.com/
#
# ...

# %%
df.columns
# to see all columns present
# Out:
# Index(['Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df.dtypes
# to get the data types of all columns
# Out:
# Organization Id        object
# Name                   object
# Website                object
# Country                object
# Description            object
# Founded                 int64
# Industry               object
# Number of employees     int64
# dtype: object

# %%
df.describe()
# to describe the math stats for numerical columns
# Out:
#            Founded  Number of employees
# count   106.000000           106.000000
# mean   1995.009434          4830.179245
# std      15.664637          2854.523020
# min    1970.000000           236.000000
# 25%    1982.500000          2653.750000
# 50%    1993.000000          4873.000000
# 75%    2009.000000          7481.250000
# max    2021.000000          9995.000000

# %%
df.describe(include="object")
# to describe math stats for string and object columns
# Out:
#         Organization Id            Name                  Website Country
# count               106             106                      106     106  \
# unique              100             100                      100      84
# top     e9eB5A60Cef8354  Watkins-Kaiser  http://www.herring.com/  Sweden
# freq                  2               2                        2       3
#
#                           Description  Industry
# count                             106       106
# unique                            100        72
# top     Synergistic background access  Plastics
# freq                                2         4

# %%
df.Website
# Out:
# 0                  https://price.net/
# 1      http://www.hall-buchanan.info/
# 2           http://sullivan-reed.com/
# 3                 https://becker.com/
# 4              http://www.brewer.com/
#                     ...
# 101             https://mcdowell.org/
# 102                 http://duffy.com/
# 103           http://www.flowers.net/
# 104            https://www.burke.net/
# 105           http://www.herring.com/
# Name: Website, Length: 106, dtype: object

# %%
df['Organization Id']
# Out:
# 0      FAB0d41d5b5d22c
# 1      6A7EdDEA9FaDC52
# 2      0bFED1ADAE4bcC1
# 3      2bFC1Be8a4ce42f
# 4      9eE8A6a4Eb96C24
#             ...
# 101    0a0bfFbBbB8eC7c
# 102    BA6Cd9Dae2Efd62
# 103    E7df80C60Abd7f9
# 104    AFc285dbE2fEd24
# 105    e9eB5A60Cef8354
# Name: Organization Id, Length: 106, dtype: object

# %%
df[['Name','Website']]
# Out:
#                         Name                         Website
# 0                Ferrell LLC              https://price.net/
# 1    Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2                 Hester Ltd       http://sullivan-reed.com/
# 3             Holder-Sellers             https://becker.com/
# 4                Mayer Group          http://www.brewer.com/
# ..                       ...                             ...
# 101             Holmes Group           https://mcdowell.org/
# 102                 Good Ltd               http://duffy.com/
# 103        Clements-Espinoza         http://www.flowers.net/
# 104               Mendez Inc          https://www.burke.net/
# 105           Watkins-Kaiser         http://www.herring.com/
#
# [106 rows x 2 columns]

# %%
df.Country.unique()
# Out:
# array(['Papua New Guinea', 'Finland', 'China', 'Turkmenistan',
#        'Mauritius', 'Bahamas', 'Pakistan',
#        'Heard Island and McDonald Islands', 'Kuwait', 'Uzbekistan',
#        'Bouvet Island (Bouvetoya)', 'Denmark', 'Liberia',
#        'United Arab Emirates', 'Sweden', 'Honduras', 'Uganda',
#        'Hong Kong', 'Botswana', 'Korea', 'Luxembourg', 'Guadeloupe',
#        'Monaco', 'Belgium', 'South Africa', 'Romania', 'Czech Republic',
#        'Christmas Island', 'Philippines', 'Australia', 'Chad', 'Zimbabwe',
#        'Nepal', 'Taiwan', 'Kyrgyz Republic', 'Bolivia', 'Kenya',
#        'Guatemala', 'Belarus', 'Jersey', 'Grenada', 'Cape Verde',
#        'Trinidad and Tobago', 'Benin', 'Western Sahara',
#        'Northern Mariana Islands', 'Germany', 'Canada', 'Tonga',
#        'French Southern Territories', "Cote d'Ivoire", 'Mayotte',
#        'Cayman Islands', 'Nigeria', 'Marshall Islands', 'Palau', 'Turkey',
# ...

# %%
df.head()
# Out:
#    Organization Id                     Name                         Website
# 0  FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1  6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2  0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 3  2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 4  9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
#
#             Country                                     Description  Founded
# 0  Papua New Guinea             Horizontal empowering knowledgebase     1990  \
# 1           Finland             User-centric system-worthy leverage     2015
# 2             China                  Switchable scalable moratorium     1971
# 3      Turkmenistan  De-engineered systemic artificial intelligence     2004
# 4         Mauritius              Synchronized needs-based challenge     1991
#
# ...

# %%
df[df['Country']=='United States Virgin Islands']
# Out:
#     Organization Id                           Name
# 65  fdFbecbadcdCdf1  Wilkinson, Charles and Arroyo  \
# 87  8cC1bDa330a5871                  Pineda-Morton
#
#                          Website                       Country
# 65  http://hunter-mcfarland.com/  United States Virgin Islands  \
# 87         https://www.carr.com/  United States Virgin Islands
#
#                               Description  Founded            Industry
# 65               Assimilated 24/7 archive     1996  Building Materials  \
# 87  Grass-roots methodical info-mediaries     1991            Printing
#
#     Number of employees
# 65                  602
# 87                 6168

# %%
df[df.Founded==1996]
# Out:
#     Organization Id                           Name
# 8   0B4F93aA06ED03e                       Carr Inc  \
# 65  fdFbecbadcdCdf1  Wilkinson, Charles and Arroyo
# 91  4e0719FBE38e0aB                Miles-Dominguez
#
#                          Website                       Country
# 8               http://ross.com/                        Kuwait  \
# 65  http://hunter-mcfarland.com/  United States Virgin Islands
# 91        http://www.turner.com/                     Gibraltar
#
#                                Description  Founded
# 8   Distributed impactful customer loyalty     1996  \
# 65                Assimilated 24/7 archive     1996
# 91           Organized empowering forecast     1996
#
#                        Industry  Number of employees
# 8                      Plastics                 8167
# 65           Building Materials                  602
# 91  Civic / Social Organization                  897

# %%
df[(df.Country=='United States Virgin Islands') & (df.Founded==1996)]
# Out:
#     Organization Id                           Name
# 65  fdFbecbadcdCdf1  Wilkinson, Charles and Arroyo  \
#
#                          Website                       Country
# 65  http://hunter-mcfarland.com/  United States Virgin Islands  \
#
#                  Description  Founded            Industry  Number of employees
# 65  Assimilated 24/7 archive     1996  Building Materials                  602

# %%
df.iloc[0]
# to get data based on row index
# Out:
# Organization Id                            FAB0d41d5b5d22c
# Name                                           Ferrell LLC
# Website                                 https://price.net/
# Country                                   Papua New Guinea
# Description            Horizontal empowering knowledgebase
# Founded                                               1990
# Industry                                          Plastics
# Number of employees                                   3498
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# Organization Id                      e9eB5A60Cef8354
# Name                                  Watkins-Kaiser
# Website                      http://www.herring.com/
# Country                                         Togo
# Description            Synergistic background access
# Founded                                         2009
# Industry                          Financial Services
# Number of employees                             2785
# Name: 105, dtype: object

# %%
df.iloc[45:50]
# Out:
#     Organization Id                        Name
# 45  1eD64cFe986BBbE              Walton-Barnett  \
# 46  CbBbFcdd0eaE2cF             Bartlett-Arroyo
# 47  49aECbDaE6aBD53  Wallace, Madden and Morris
# 48  7b3fe6e7E72bFa4                 Berg-Sparks
# 49  c6DedA82A8aef7E                Gonzales Ltd
#
#                               Website                   Country
# 45       https://ashley-schaefer.com/            Western Sahara  \
# 46                  https://cruz.com/  Northern Mariana Islands
# 47  http://www.blevins-fernandez.biz/                   Germany
# 48         https://cisneros-love.com/                    Canada
# 49                   http://bird.com/                     Tonga
#
#                                Description  Founded
# 45  Right-sized clear-thinking flexibility     2001  \
# 46             Realigned didactic function     1976
# 47   Persistent real-time customer loyalty     2016
# 48       Stand-alone static implementation     1974
# ...

# %%
cdf=df.copy()
cdf.set_index('Organization Id')
# Out:
#                                     Name                         Website
# Organization Id
# FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
# ...                                  ...                             ...
# 0a0bfFbBbB8eC7c             Holmes Group           https://mcdowell.org/
# BA6Cd9Dae2Efd62                 Good Ltd               http://duffy.com/
# E7df80C60Abd7f9        Clements-Espinoza         http://www.flowers.net/
# AFc285dbE2fEd24               Mendez Inc          https://www.burke.net/
# e9eB5A60Cef8354           Watkins-Kaiser         http://www.herring.com/
#
#                                      Country
# Organization Id
# ...

# %%
# cdf.loc(['AFc285dbE2fEd24'],axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 cdf.loc(['AFc285dbE2fEd24'],axis=0)
#
# TypeError: _LocationIndexer.__call__() got multiple values for argument 'axis'

# %%
# dropping columns 
# cdf.drop(columns=['Website','Country'])

# dropping rows based on index 
# cdf.drop([0,2])

# drop columns based on axis 
# cdf.drop([],axis=1)

# cdf.drop(labels=[])
# Out:
#      Organization Id                     Name                         Website
# 0    FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1    6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 4    9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
# 5    cC757116fe1C085           Henry-Thompson               http://morse.net/
# 6    219233e8aFF1BC3           Hansen-Everett           https://www.kidd.org/
# ..               ...                      ...                             ...
# 101  0a0bfFbBbB8eC7c             Holmes Group           https://mcdowell.org/
# 102  BA6Cd9Dae2Efd62                 Good Ltd               http://duffy.com/
# 103  E7df80C60Abd7f9        Clements-Espinoza         http://www.flowers.net/
# 104  AFc285dbE2fEd24               Mendez Inc          https://www.burke.net/
# 105  e9eB5A60Cef8354           Watkins-Kaiser         http://www.herring.com/
#
#                          Country
# ...

# %%
df['mhund']=100
df
# Out:
#      Organization Id                     Name                         Website
# 0    FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1    6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2    0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 3    2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 4    9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
# ..               ...                      ...                             ...
# 101  0a0bfFbBbB8eC7c             Holmes Group           https://mcdowell.org/
# 102  BA6Cd9Dae2Efd62                 Good Ltd               http://duffy.com/
# 103  E7df80C60Abd7f9        Clements-Espinoza         http://www.flowers.net/
# 104  AFc285dbE2fEd24               Mendez Inc          https://www.burke.net/
# 105  e9eB5A60Cef8354           Watkins-Kaiser         http://www.herring.com/
#
#                          Country
# ...

# %%
df.iloc[1,5]=2018
df.head()
# Out:
#    Organization Id                     Name                         Website
# 0  FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1  6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2  0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 3  2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 4  9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
#
#             Country                                     Description  Founded
# 0  Papua New Guinea             Horizontal empowering knowledgebase     1990  \
# 1           Finland             User-centric system-worthy leverage     2018
# 2             China                  Switchable scalable moratorium     1971
# 3      Turkmenistan  De-engineered systemic artificial intelligence     2004
# 4         Mauritius              Synchronized needs-based challenge     1991
#
# ...

# %%
df['slaray']=df['Number of employees'] * 5000 * 12
df
# Out:
#      Organization Id                     Name                         Website
# 0    FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1    6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2    0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 3    2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 4    9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
# ..               ...                      ...                             ...
# 101  0a0bfFbBbB8eC7c             Holmes Group           https://mcdowell.org/
# 102  BA6Cd9Dae2Efd62                 Good Ltd               http://duffy.com/
# 103  E7df80C60Abd7f9        Clements-Espinoza         http://www.flowers.net/
# 104  AFc285dbE2fEd24               Mendez Inc          https://www.burke.net/
# 105  e9eB5A60Cef8354           Watkins-Kaiser         http://www.herring.com/
#
#                          Country
# ...

# %%
def doSomething(x):
    if(x>3000):
        return True
    
    return False

df['taxp']=df['Number of employees'].apply(doSomething)
df
# Out:
#      Organization Id                     Name                         Website
# 0    FAB0d41d5b5d22c              Ferrell LLC              https://price.net/  \
# 1    6A7EdDEA9FaDC52  Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 2    0bFED1ADAE4bcC1               Hester Ltd       http://sullivan-reed.com/
# 3    2bFC1Be8a4ce42f           Holder-Sellers             https://becker.com/
# 4    9eE8A6a4Eb96C24              Mayer Group          http://www.brewer.com/
# ..               ...                      ...                             ...
# 101  0a0bfFbBbB8eC7c             Holmes Group           https://mcdowell.org/
# 102  BA6Cd9Dae2Efd62                 Good Ltd               http://duffy.com/
# 103  E7df80C60Abd7f9        Clements-Espinoza         http://www.flowers.net/
# 104  AFc285dbE2fEd24               Mendez Inc          https://www.burke.net/
# 105  e9eB5A60Cef8354           Watkins-Kaiser         http://www.herring.com/
#
#                          Country
# ...

# %%
df.to_csv('newdata.csv')

# %%
df.to_json('data.json')

# %%
df.to_html('data.html')

# %%
df.to_clipboard()

# %%
cricket={"players":["Steyn","Anderson","Malinga"],"Wickets":[439,345,567]}
dfd=pd.DataFrame.from_dict(cricket)
dfd
# Out:
#     players  Wickets
# 0     Steyn      439
# 1  Anderson      345
# 2   Malinga      567

# %%
ls=np.array([23,45,67,88])

dc={"name":"Saurabh","age":26}

ps=pd.Series(dc)

ps
# Out:
# name    Saurabh
# age          26
# dtype: object
